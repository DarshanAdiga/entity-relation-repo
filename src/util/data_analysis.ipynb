# %%
import pandas as pd
import json

pd.options.display.max_rows = 600
pd.set_option('max_colwidth', 400)

# %%
base_dir = '/home/adiga/my_work/entity-relation-repo/data/'
in_file_path = base_dir + 'parsed_data.jl'

# %%
in_file = open(in_file_path, 'r')
in_data = []
for l in in_file:
    in_data.append(json.loads(l))

df_relations = pd.DataFrame(in_data)

# %%
# Clean the text 
# /\n\t\t\t
# KPMG’s 
# \n\n
# Mumbai: Indian banking services, apart ...
# service — key staff will be...
# “We request all our...suspended,”
# Better communication (is needed) to let...

# %%
df_relations
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                      entities  \
# 0                                                                                                                                                                                                                                                         [{"token": "Ballarpur Industries Limited", "label": "ORG"}, {"token": "KSK Mahanadi Power", "label": "ORG"}, {"token": "two", "label": "CARDINAL"}]
# 1                                                                                                                                                                                                                                                                                                                                                                                                          []
# 2                                                                                                                                                                                                                                                                                                                [{"token": "Sumit Binani", "label": "ORG"}, {"token": "KSK Mahanadi Power", "label": "ORG"}]
# 3                                                                                                                                                                                                                                                                                                                                                                                                          []
# 4                                                                                                                                                                                                                                                                                                                              [{"token": "Jain", "label": "PERSON"}, {"token": "Binani", "label": "PERSON"}]
# 5                                                                                                                                                                                                                                                                                                                                       [{"token": "CoC", "label": "ORG"}, {"token": "NCLT", "label": "ORG"}]
# 6                                                                                                                                                                                                                                                                                                                                                                          [{"token": "CoC", "label": "ORG"}]
# 7                                                                                                                                                                                                                                                                                                                            [{"token": "IDBI Bank", "label": "ORG"}, {"token": "2000", "label": "CARDINAL"}]
# 8                                                                                                                                                                                                                                                                                                              [{"token": "KSK Mahanadi Power", "label": "PERSON"}, {"token": "15,000", "label": "CARDINAL"}]
# 9                                                                                                                                                                                       [{"token": "2NextPrevPlay", "label": "CARDINAL"}, {"token": "2020Product", "label": "ORDINAL"}, {"token": "Labeling-1NextRiskometer23 Mar", "label": "PERSON"}, {"token": "2020RiskometerNext", "label": "CARDINAL"}]
# 10                                                                                                                                                                                                                                                                                                                                                                                                         []
# 11                                                                                                                                                                                                                                                                                                                                                                                                         []
# 12                                                                                                                                                                                                                                                                                                                                                                                                         []
# 13                                                                                                                                                                                                                                                                                                                                                        [{"token": "Axis Focused 25 Fund", "label": "ORG"}]
# 14                                                                                                                                                                                                                                                                                                                                                                     [{"token": "25", "label": "CARDINAL"}]
# 15                                                                                                                                                                                                                                                                                                                            [{"token": "Axis", "label": "ORG"}, {"token": "up to 25", "label": "CARDINAL"}]
# 16                                                                                                                                                                                                                                                                                                                                  [{"token": "Axis", "label": "ORG"}, {"token": "25", "label": "CARDINAL"}]
# 17                                                                                                                                                                                                                                                                                                                                                                                                         []
# 18                                                                                                                                                                                                                                                                                                                                                            [{"token": "Axis Mutual Fund", "label": "ORG"}]
# 19                                                                                                                                                                                                                                                                                                                                [{"token": "Mumbai", "label": "GPE"}, {"token": "Indian", "label": "NORP"}]
# 20                                                                                                                                                                                                                                                                                                                                                                                                         []
# 21                                                                                                                                                                                                                                                                                                                                     [{"token": "the Indian Banks\u2019 Association (IBA", "label": "ORG"}]
# 22                                                                                                                                                                                                                                                                                                                                                                                                         []
# 23                                                                                                                                                                                                                                                                                                                                                                                                         []
# 24                                                                                                                                                                                                                                                                                                                                                                                                         []
# 25                                                                                                                                                                                                                                                                                                                                                                                                         []
# 26                                                                                                                                                                                                                                                                                                                                                                                                         []
# 27                                                                                                                                                                                                                                                                                                                 [{"token": "Romesh Sobti", "label": "PERSON"}, {"token": "IndusInd Bank", "label": "ORG"}]
# 28                                                                                                                                                                                                                                                                                                                                                                  [{"token": "three", "label": "CARDINAL"}]
# 29                                                                                                                                                                                                                                                                                                                                                        [{"token": "the last week or so", "label": "DATE"}]
# 30                                                                                                                                                                                                                                                                                                                                                                                                         []
# 31                                                                                                                                                                                                                                                                                                                                                                                                         []
# 32                                                                                                                                                                                                                                                                                                                                                                  [{"token": "last week", "label": "DATE"}]
# 33                                                                                                                                                                                                                                                                                                                                                                                                         []
# 34                                                                                                                                                                                                                                                                                         [{"token": "RBI", "label": "ORG"}, {"token": "two", "label": "CARDINAL"}, {"token": "second", "label": "ORDINAL"}]
# 35                                                                                                                                                                                                                                                                                                                                                                                                         []
# 36                                                                                                                                                                                                                                                                                                                                   [{"token": "37", "label": "CARDINAL"}, {"token": "RBI", "label": "ORG"}]
# 37                                                                                                                                                                                                                                                                                                                         [{"token": "Mumbai", "label": "GPE"}, {"token": "about 150", "label": "CARDINAL"}]
# 38                                                                                                                                                                                                                                                                                                                                                               [{"token": "about 69", "label": "CARDINAL"}]
# 39                                                                                                                                                                                                                                                                                                                                                                                                         []
# 40                                                                                                                                                                                                    [{"token": "HDFC Bank", "label": "ORG"}, {"token": "Kotak Mahindra Bank", "label": "ORG"}, {"token": "Axis Bank", "label": "ORG"}, {"token": "Bank of Baroda and State Bank of India", "label": "ORG"}]
# 41                                                                                                                                                                                                                                                                                                                                                                                                         []
# 42                                                                                                                                                                                                                                                                                                                                                                         [{"token": "BCP", "label": "ORG"}]
# 43                                                                                                                                                                                                                                                                                                         [{"token": "Bandhan Bank", "label": "ORG"}, {"token": "Chandra Shekhar Ghosh", "label": "PERSON"}]
# 44                                                                                                                                                                                                                                                                                               [{"token": "the National Payments Corporation of India", "label": "ORG"}, {"token": "NCPI", "label": "ORG"}]
# 45                                                                                                                                                                                                                                                                                                                                                                                                         []
# 46                                                                                                                                                                                                                                                                                                                                                                   [{"token": "Saturday", "label": "DATE"}]
# 47                                                                                                                                                                                                                                                                                         [{"token": "March", "label": "DATE"}, {"token": "year-end", "label": "DATE"}, {"token": "Mumbai", "label": "GPE"}]
# 48                                                                                                                                                                                                                                                                                                                                                                                                         []
# 49                                                                                                                                                                                                                                                                                                                                                                   [{"token": "March 31", "label": "DATE"}]
# 50                                                                                                               [{"token": "Parthasarathi Mukherjee", "label": "PERSON"}, {"token": "Lakshmi Vilas Bank", "label": "ORG"}, {"token": "Axis Bank", "label": "ORG"}, {"token": "5 percent", "label": "PERCENT"}, {"token": "Uttrayan Financial Services", "label": "ORG"}, {"token": "India", "label": "GPE"}]
# 51                                                                                                                                                                                    [{"token": "2.8 percent", "label": "PERCENT"}, {"token": "Kolkata", "label": "GPE"}, {"token": "four", "label": "CARDINAL"}, {"token": "LVB/Axis Bank", "label": "ORG"}, {"token": "2.48 percent", "label": "PERCENT"}]
# 52                                                                                                                                                                                                                                                                                                                                                                    [{"token": "Uttrayan", "label": "ORG"}]
# 53                                                                                                                                                                                                                                                                                                                                  [{"token": "Mukherjee", "label": "GPE"}, {"token": "ET", "label": "ORG"}]
# 54                                                                                                                                                                                                                                                                                                                                                                                                         []
# 55                                                                                                                                                                                                                                                                                                                 [{"token": "IndusInd Bank", "label": "ORG"}, {"token": "IDFC First Bank", "label": "ORG"}]
# 56                                                                                                                                                                                                                                                                 [{"token": "Bandhan Bank", "label": "ORG"}, {"token": "about two decades ago", "label": "DATE"}, {"token": "32,000", "label": "CARDINAL"}]
# 57                                                                                                                                                                                                                                   [{"token": "225", "label": "CARDINAL"}, {"token": "Mukherjee", "label": "GPE"}, {"token": "Lakshmi Vilas Bank", "label": "ORG"}, {"token": "Axis Bank", "label": "ORG"}]
# 58                                                                                                                                                                                                                                                                                                       [{"token": "30", "label": "CARDINAL"}, {"token": "the next seven to eight months", "label": "DATE"}]
# 59                                                                                                                                                                                                                                                                            [{"token": "Mukherjee", "label": "GPE"}, {"token": "Uttrayan", "label": "ORG"}, {"token": "Kartick Biswas", "label": "PERSON"}]
# 60                                                                                                                                                                                                                                                                                          [{"token": "LVB", "label": "ORG"}, {"token": "Mukherjee", "label": "GPE"}, {"token": "Uttrayan", "label": "ORG"}]
# 61                                                                                                                                                                                                                                                                                                                                                            [{"token": "August 29, 2019", "label": "DATE"}]
# 62                         [{"token": "Sridhar Rallabandi", "label": "PERSON"}, {"token": "Axis Bank", "label": "ORG"}, {"token": "LVB", "label": "ORG"}, {"token": "1%", "label": "PERCENT"}, {"token": "Axis Bank", "label": "ORG"}, {"token": "JP Singh", "label": "PERSON"}, {"token": "Bapi Munshi", "label": "PERSON"}, {"token": "0.86%", "label": "PERCENT"}, {"token": "0.72%", "label": "PERCENT"}]
# 63                                                                                                                                                                                                                               [{"token": "Axis Securities", "label": "ORG"}, {"token": "Arun Thukral", "label": "PERSON"}, {"token": "0.72%", "label": "PERCENT"}, {"token": "Biswas", "label": "PERSON"}]
# 64                                                                                                                                        [{"token": "24%", "label": "PERCENT"}, {"token": "2.11", "label": "CARDINAL"}, {"token": "the end of December 2019", "label": "DATE"}, {"token": "Assam", "label": "NORP"}, {"token": "Karnataka", "label": "PERSON"}, {"token": "Maharashtra", "label": "PERSON"}]
# 65                                                                                                                                                                                                                                                                                                                                                                   [{"token": "5.64", "label": "CARDINAL"}]
# 66   [{"token": "1.28", "label": "CARDINAL"}, {"token": "eight", "label": "CARDINAL"}, {"token": "Assam", "label": "NORP"}, {"token": "Bihar", "label": "GPE"}, {"token": "Odisha", "label": "GPE"}, {"token": "Meghalaya", "label": "PERSON"}, {"token": "Punjab", "label": "ORG"}, {"token": "Sikkim", "label": "GPE"}, {"token": "Uttarakhand", "label": "GPE"}, {"token": "West Bengal", "label": "GPE"}]
# 67                                                                                                                                                                                                                                                                                           [{"token": "Kolkata", "label": "GPE"}, {"token": "Monday", "label": "DATE"}, {"token": "India", "label": "GPE"}]
# 68                                                                                                                                                                                                                                                                                                                                                                                                         []
# 69                                                                                                                                                                                                                                                                                                                                                   [{"token": "Indian Banks' Association", "label": "ORG"}]
# 70                                                                                                                                                                                                                                                                                                                                                                                                         []
# 71                                                                                                                                                                                                                                                                                                                             [{"token": "75", "label": "CARDINAL"}, {"token": "March 31", "label": "DATE"}]
# 72                                                                                                                                                                                                                                                                                                                                                                                                         []
# 73                                                                                                                                                                                                                                                                                                                                                               [{"token": "about 50%", "label": "PERCENT"}]
# 74                                                                                                                                                                                                                                                                                                                                                                                                         []
# 75                                                                                                                                                                                                                                                                                                                                                                   [{"token": "two days", "label": "DATE"}]
# 76                                                                                                                                                                                                                                                                                                                                                                      [{"token": "today", "label": "DATE"}]
# 77                                                                                                                                                                                                                                                                                                                                                                         [{"token": "IBA", "label": "ORG"}]
# 78                                                                                                                                                                                                                                                                                   [{"token": "the Hotel & Restaurant Association of Eastern India", "label": "ORG"}, {"token": "Kolkata", "label": "GPE"}]
# 79                                                                                                                                                       [{"token": "Monday", "label": "DATE"}, {"token": "around 500", "label": "CARDINAL"}, {"token": "metropolis", "label": "NORP"}, {"token": "415", "label": "CARDINAL"}, {"token": "41", "label": "CARDINAL"}, {"token": "seven", "label": "CARDINAL"}]
# 80                                                                                                                                                                                                                                                                                                                                  [{"token": "500", "label": "CARDINAL"}, {"token": "PTI", "label": "ORG"}]
# 81                                                                                                                                                                                                                                                                                                                                                                                                         []
# 82                                                                                                                                                                                                                                                                                                                                                                      [{"token": "Poddar", "label": "ORG"}]
# 83                                                                                                                                                                                                                                                                                                                                                                                                         []
# 84                                                                                                                                                                                                                                                                                                                                                                                                         []
# 85                                                                                                                                                                                                                                                                                                                                                                                                         []
# 86                                                                                                                                                                                                                                                                                                                                                                      [{"token": "Poddar", "label": "ORG"}]
# 87                                                                                                                                                                                                                                                                                                                                                          [{"token": "close to zero", "label": "CARDINAL"}]
# 88                                                                                                                                                                                                                                                           [{"token": "NCR", "label": "ORG"}, {"token": "Delhi", "label": "GPE"}, {"token": "Noida", "label": "GPE"}, {"token": "Gurgaon", "label": "ORG"}]
# 89                                                                                                                                                                                                                                                                                                                                                                   [{"token": "Supertech", "label": "ORG"}]
# 90                                                                                                                                                                                                                                                                                          [{"token": "Capetown", "label": "GPE"}, {"token": "74", "label": "CARDINAL"}, {"token": "Noida", "label": "GPE"}]
# 91                                                                                                                                                                                                                                                                                                                                                                                                         []
# 92                                                                                                                                                                                                                                                                                                                         [{"token": "RK Arora", "label": "PERSON"}, {"token": "supertech", "label": "ORG"}]
# 93                                                                                                                                                                                                                                                                                                                                                                                                         []
# 94                                                                                                                                                                                                                                                                                  [{"token": "Golf", "label": "ORG"}, {"token": "Gurugram", "label": "GPE"}, {"token": "every two hours", "label": "TIME"}]
# 95                                                                                                                                                                                                                                                                                                                                                                                                         []
# 96                                                                                                                                                                                                                                                                                                                                                                                                         []
# 97                                                                                                                                                                                                                                                                                                                                                              [{"token": "the Golf Gates", "label": "FAC"}]
# 98                                                                                                                                                                                                                                                                                                                                                                                                         []
# 99                                                                                                                                                                                                                                                                                                                                                                                                         []
# 100                                                                                                                                                                                                                                                                                                                                                                                                        []
# 101                                                                                                                                                                                                                                                                                                                                                                                                        []
# 102                                                                                                                                                                                                                                                                                                                                                             [{"token": "Ankur Gupta", "label": "PERSON"}]
# 103                                                                                                                                                                                                                                                                                                                                                                    [{"token": "Anarock", "label": "ORG"}]
# 104                                                                                                                                                                                                                                                                                                                                                                                                        []
# 105                                                                                                                                                                                                                                                                                                                                                                                                        []
# 106                                                                                                                                                                                                                                                                                                                                                                [{"token": "Anarock", "label": "PRODUCT"}]
# 107                                                                                                                                                                                                                                                                                                                                                                                                        []
# 108                                                                                                                                                                                                                [{"token": "India", "label": "GPE"}, {"token": "Mansoor Dalal", "label": "PERSON"}, {"token": "Founder", "label": "ORG"}, {"token": "Association of Senior Living India", "label": "ORG"}]
# 109                                                                                                                                                                                                                                                                                        [{"token": "Monday", "label": "DATE"}, {"token": "India", "label": "GPE"}, {"token": "March 31", "label": "DATE"}]
# 110                                                                                                                                                                     [{"token": "Karnataka", "label": "GPE"}, {"token": "Tamil Nadu", "label": "PERSON"}, {"token": "Odisha", "label": "ORG"}, {"token": "March 31, 2020", "label": "DATE"}, {"token": "Aditya Birla Fashion and Retail", "label": "ORG"}]
# 111                                                                                                                                                                                                                                                                                                                                                            [{"token": "March 31, 2020", "label": "DATE"}]
# 112                                                                                                                                                                                                                                                                                                                                                                                                        []
# 113                                                                                                                                                                                                                                                                                                                                                        [{"token": "the last few weeks", "label": "DATE"}]
# 114                                                                                                                                                                                                                                                                                                                                                                                                        []
# 115                                                                                                                                                                                                                                                                                                                                                                                                        []
# 116                                                                                                                                                                                 [{"token": "8,118", "label": "CARDINAL"}, {"token": "7.5 million", "label": "CARDINAL"}, {"token": "March 31, 2019", "label": "DATE"}, {"token": "India", "label": "GPE"}, {"token": "billion-dollar", "label": "MONEY"}]
# 117                                                                                                                                                                                                                                                                                                                          [{"token": "2,714", "label": "CARDINAL"}, {"token": "750", "label": "CARDINAL"}]
# ...
# 102                                                                      Since senior residents are at a significantly higher risk of infection and slower recovery, we are taking extra measures to regularly disinfect senior living premises, and our staff is taking all precautions to keep themselves sanitised and disinfected at all times,” said Ankur Gupta,
# 103                                                                                                                                                                          According to Anarock property consultants, senior living homes have become a respectable real estate category - one which, in times of the COVID-19 scare, gains even more relevance.\n\n
# 104                                                                                                                                                                                            “The aged are a high-risk group for the novel coronavirus - senior living projects have healthcare staff, scalable facilities and processes in place to keep them safe.
# 105                                                                                                                                                                                                                                  In-house doctors and nursing, rapid access to hospitals and strict sanitation processes are not found in normal housing projects.
# 106                                                                                                                                                                                                                                                                                                  To meet the objective of maintaining a vibrant,” Anarock said. \n
# 107                                                                                                                                                                                                                                                             “At this moment, it is important that each one of us do our bit in controlling the spread of COVID-19.
# 108  all our senior living and assisted communities across India have undertaken necessary precautionary measures to protect their residents and are promoting healthy, safe and secured living., for their residents , who incidentally are the most vulnerable, at this juncture,” said Mansoor Dalal, Founder and Chairman, Association of Senior Living India.\n\n
# 109                                                                                                                                                                          on Monday said it will shut all its retail stores across India till March 31, in order to ensure safety of its employees across all its establishments from the coronavirus pandemic.\n\n
# 110                                                                                                                                                   The company has also stopped its factory operations in Karnataka, Tamil Nadu and Odisha till March 31, 2020, in line with the local guidelines, Aditya Birla Fashion and Retail said in a regulatory filing.\n\n
# 111                                                                                                       In order to safeguard the risks to the health of our store employees & customers, as well as in line with the advisories from local, state and central government, the company has decided to shut all its retail stores until March 31, 2020," it said.\n\n
# 112                                                                                                                                                                                                                                                                         The company had already moved to "work from home" policy for all its office employees.\n\n
# 113                                                                                                                                                                                                        "The business of the company has been significantly affected over the last few weeks and will continue to be materially impacted due to the current crisis.
# 114                                                                                                                                                                                                                                The uncertainty around the situation makes it difficult to ascertain the exact impact at this point of time," the company said.\n\n
# 115                                                                                                                                                                                                      The company further noted that "it will continue to assess the situation and will consider resumption of its business operations at an appropriate time".\n\n
# 116                                                                                                                                                                                           ABFRL, with revenue of Rs 8,118 crore and with a retail space of 7.5 million sq ft (as on March 31, 2019), is India's first billion-dollar pure-play fashion powerhouse.
# 117                                                                                                                                                                                                                                                                                       It has a network of 2,714 brand stores across 750 cities in the country.\n\n
# 118                                                                                                                                                                                                           Shares of Aditya Birla Fashion and Retail Ltd were trading at Rs 176.35, on BSE in the afternoon trade, down 5.62 per cent over its previous close. \n\n
# 119                       Ecommerce operators were forced to cancel or reschedule lakhs of orders for essential goods such as food, groceries and medicines across several cities on Sunday as local authorities and the police ordered them to shut warehouses, blocked trucks carrying supplies and dissuaded delivery agents from moving around on the streets.\n\n
# 120                                                                 The action against grocery e-tailers such as Grofers, BigBasket and e-pharmacy player 1mg and their on-ground staff, apart from larger firms Flipkart and Amazon, comes despite ecommerce being exempt from Section 144-type restrictions that have been imposed by several states in the country.
# 121                                                                                                                                                                                                                 “There was some confusion on the ground as the message from central government was not clear to local authorities as to what needed to be allowed.
# 122                                                                                                                       Better communication (is needed) to let services like Grofers, BigBasket or 1mg be allowed to operate will help make sure the flow of essential items to a self-quarantined India doesn’t stop,” Albinder Dhindsa, CEO, Grofers told ET.\n\n
# 123                                                                                                                                                                                                                                                                                          The egrocer cancelled or rescheduled as many as 170,000 orders on Sunday.
# 124                                                                                                                                                                                                   Dhindsa said his field staff reported trucks bringing supplies to its warehouses being stopped in Uttar Pradesh, Maharashtra, Karnataka and Telangana.\n\n\n\n\n
# 125                                                                                                                                                                    ‘Ensuring Minimal Disruption’\nApart from this, the company also said authorities in Maharashtra and Haryana had forced its warehouses to shut down in view of the Janata Curfew on Sunday.\n\n
# 126                                                                                                                                         BigBasket, the country’s largest online grocery, also complained of facing similar issues, which has been leading to delayed deliveries and an inability to accept any new orders in several locations across the country.
# 127                                                                                                                                                                                           “We felt very let down by how the local authorities in almost all cities executed stopping deliveries and even beating up people,” a BigBasket spokesperson told ET.\n\n
# 128                                                                                                                  A senior government official confirmed to ET that he had received several complaints from ecommerce firms and industry bodies with regard to trouble they were facing from local authorities who were forcing them to shut down their operations.
# 129                                                                                                                                                     “We are coordinating and communicating all instances of trouble these companies are facing with secretaries at the state level to take action and ensure there is minimal disruption,” the official added.\n\n
# 130                                                                                                                                                                     The action against ecommerce players on Sunday comes on the back of a few warehouses being shuttered by local authorities since the last one week, another person aware of the matter told ET.
# 131                                                                                                                                       This despite the ministry of consumer affairs on Friday notifying that ecommerce firms, their warehouses and logistics facilities, wholesalers, vendors and delivery partners be exempt from any type of prohibitory orders.
# 132                                                                                                                                                                                                                                                    The move was aimed at ensuring supply of essentials to consumer doorsteps did not stop or face any hurdles.\n\n
# 133                                                                                                                                                                                                                                                                  Even medicine deliveries and other at-home medical services were disrupted across several cities.
# 134                                                                                                                                                                      1mg, an e-pharmacy and online diagnostics provider, said some of its Pre Analytical Centres, that run diagnostics on samples picked up at home were asked to shut in Delhi, Patna and Mumbai.
# 135                                                                                                                                                                                                                                   The company added that delivery agents were stopped by the police in south Delhi, Hyderabad, Lucknow, Faridabad and Gurgaon.\n\n
# 136                                                                                                                                                                              “It seems that there is a need for clear guidance and notification for the police teams on ground, telling them that essential services should not face any issues during this phase.
# 137                                                                                                                                                                                                              As of now, it seems there is lack of clarity and they are stopping all activity, including essential services,” said Prashant Tandon, CEO of 1mg.\n\n
# 138                                                                                                                                                                                                                  Grocery deliverers are seeing as much as a five-fold increase in order volumes as many large format stores remain shut and people stayed indoors.
# 139                                                                                                                                                                                                                                                                 The average order value for e-grocers has increased by 20-25%, executives at these companies said.
# 140                                                                                                                                                                                                                                                        On Thursday, both Grofers and BigBasket faced brief outages amid panic buying, as reported by ET last week.
# 141                                                                                                                                                                                                                                             The demand is expected to get further amplified as many states declare Section 144 to stop the spread of Covid-19.\n\n
# 142                                                                       The Confederation of Indian Industry has urged the government to exempt services such as e-commerce including delivery boys and supply chain vendors, food processing warehousing and IT-ITeS from the imposition of section 144 and other similar directives amid the coronavirus outbreak.
# 143                                                                                                                                                                                                                                                 The appeal gains significance as more and more states are imposing lockdowns with the spread of coronavirus. \n\n
# 144                                                                       For safeguarding the uninterrupted supply of consumer items in the market, CII urges the government to keep the manufacturing facilities of the food processing industry open under the strictest of safety and hygiene guidelines," Chandrajit Banerjee, Director General, CII, said. \n\n
# 145                                                                                                                                                                                                   He also added that any executive order or section 144 restrictions should include the exemption for these manufacturing facilities and food delivery services.\n
